# %% [markdown]
# <a href="https://colab.research.google.com/github/usnhee/TIL-/blob/master/infect_per.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -*- coding: utf-8 -*-
"""
Created on Thu Feb 24 09:51:16 2022

@author: class
"""

import pandas as pd 

df = pd.read_excel('covid_name.xlsx')
df1= df.copy()
df1.rename(columns={'서추구':'서초구'}, inplace=True)

# 필터링할 마스크 생성
nor = df1['Species'] == 'normal'
beta = df1['Species'] == 'beta'
delta = df1['Species'] == 'delta'
omi = df1['Species'] == 'omicron'

# 각 종별로 필터링해서 데이터프레임 나누기 
df_nor = df1[nor]
df_beta = df1[beta]
df_delta = df1[delta]
df_omi = df1[omi]

# normal 의 확진자 인원 최대감염자수 100으로 놓고 재산출하기 
## 최댓값 열 저장 
print(df_nor.max())
df_nor_w=df_nor.copy()
df_nor_w['종로구1'] = 33
df_nor_w['중구1'] = 11
df_nor_w['용산구1'] = 28
df_nor_w['성동구1'] = 21
df_nor_w['광진구1'] = 18
df_nor_w['동대문구1'] =18
df_nor_w['중랑구1'] = 36
df_nor_w['성북구1'] = 39
df_nor_w['강북구1'] = 19
df_nor_w['도봉구1'] = 22
df_nor_w['노원구1'] = 32
df_nor_w['은평구1'] = 31
df_nor_w['서대문구1'] = 15
df_nor_w['마포구1'] = 31
df_nor_w['양천구1'] = 33
df_nor_w['강서구1'] =df_nor_w['강서구'].max()
df_nor_w['구로구1'] =df_nor_w['구로구'].max()
df_nor_w['금천구1'] =df_nor_w['금천구'].max()
df_nor_w['영등포구1'] =df_nor_w['영등포구'].max()
df_nor_w['동작구1'] =df_nor_w['동작구'].max()
df_nor_w['관악구1'] =df_nor_w['관악구'].max()
df_nor_w['서초구1'] =df_nor_w['서추구'].max()
df_nor_w['강남구1'] =df_nor_w['강남구'].max()
df_nor_w['송파구1'] =df_nor_w['송파구'].max()
df_nor_w['강동구1'] =df_nor_w['강동구'].max()
df_nor_w['기타1'] =df_nor_w['기타'].max()

df_max.rename(columns={'종로구1':'종로구', '중구1':'중구','용산구1':'용산구','성동구1':'성동구',\
                       '광진구1':'광진구','동대문구1':'동대문구', '중랑구1':'중랑구','성북구1':'성북구',\
                           '강북구1':'강북구', '도봉구1':'도봉구', '노원구1':'노원구','은평구1':'은평구',\
                               '서대문구1':'서대문구', '마포구1':'마포구', '양천구1':'양천구',\
                                   '강서구1':'강서구', '구로구1':'구로구', '금천구1':'금천구',\
                                       '영등포구1':'영등포구', '동작구1':'동작구', '관악구1':'관악구',\
                                           '서초구1':'서초구', '강남구1':'강남구', '송파구1': '송파구',\
                                               '강동구1':'강동구', '기타1':'기타'}, inplace=True)
# 최댓값만 따로 df로 만들기, 구별확진자 따로 df만듥기 
df_max=df_nor_w.loc[:,'종로구1':'기타1']
df_ori=df_nor_w.loc[:,'종로구':'기타']


## 백분위 함수 만들기 

def percen(x,y):
    # 확진자수df, 최댓값df
    result=(x/y)*100
    return result

df_new=percen(df_ori, df_max)
df_new.to_excel('normal.xlsx')

#################################### 베타
df_beta_max= df_beta.copy()
type(df_beta_max.max())

# 최댓값 매핑함수
#def infmax(x):
#    for i in x:
#        x.iloc[:,i]

# 최댓값넣기 
df_beta_max['종로구'] =df_beta_max['종로구'].max()
df_beta_max['중구'] =df_beta_max['중구'].max()
df_beta_max['용산구'] =df_beta_max['용산구'].max()
df_beta_max['성동구'] =df_beta_max['성동구'].max()
df_beta_max['광진구'] =df_beta_max['광진구'].max()
df_beta_max['동대문구'] =df_beta_max['동대문구'].max()
df_beta_max['중랑구'] =df_beta_max['중랑구'].max()
df_beta_max['성북구'] =df_beta_max['성북구'].max()
df_beta_max['강북구'] =df_beta_max['강북구'].max()
df_beta_max['도봉구'] =df_beta_max['도봉구'].max()
df_beta_max['노원구'] =df_beta_max['노원구'].max()
df_beta_max['은평구'] =df_beta_max['은평구'].max()
df_beta_max['서대문구'] =df_beta_max['서대문구'].max()
df_beta_max['마포구'] =df_beta_max['마포구'].max()
df_beta_max['양천구'] =df_beta_max['양천구'].max()
df_beta_max['강서구'] =df_beta_max['강서구'].max()
df_beta_max['구로구'] =df_beta_max['구로구'].max()
df_beta_max['금천구'] =df_beta_max['금천구'].max()
df_beta_max['영등포구'] =df_beta_max['영등포구'].max()
df_beta_max['동작구'] =df_beta_max['동작구'].max()
df_beta_max['관악구'] =df_beta_max['관악구'].max()
df_beta_max['서초구'] =df_beta_max['서초구'].max()
df_beta_max['강남구'] =df_beta_max['강남구'].max()
df_beta_max['송파구'] =df_beta_max['송파구'].max()
df_beta_max['강동구'] =df_beta_max['강동구'].max()
df_beta_max['기타'] =df_beta_max['기타'].max()

df_beta=df_beta.loc[:,'종로구':'기타']
df_beta_max=df_beta_max.loc[:,'종로구':'기타']
df_rere=percen(df_beta, df_beta_max)
df_rere.to_excel('beta.xlsx')

###########델타
#최댓값 따로 만들기 
df_delta_max= df_delta.copy()
type(df_delta_max.max())


df_delta_max['종로구'] =df_delta_max['종로구'].max()
df_delta_max['중구'] =df_delta_max['중구'].max()
df_delta_max['용산구'] =df_delta_max['용산구'].max()
df_delta_max['성동구'] =df_delta_max['성동구'].max()
df_delta_max['광진구'] =df_delta_max['광진구'].max()
df_delta_max['동대문구'] =df_delta_max['동대문구'].max()
df_delta_max['중랑구'] =df_delta_max['중랑구'].max()
df_delta_max['성북구'] =df_delta_max['성북구'].max()
df_delta_max['강북구'] =df_delta_max['강북구'].max()
df_delta_max['도봉구'] =df_delta_max['도봉구'].max()
df_delta_max['노원구'] =df_delta_max['노원구'].max()
df_delta_max['은평구'] =df_delta_max['은평구'].max()
df_delta_max['서대문구'] =df_delta_max['서대문구'].max()
df_delta_max['마포구'] =df_delta_max['마포구'].max()
df_delta_max['양천구'] =df_delta_max['양천구'].max()
df_delta_max['강서구'] =df_delta_max['강서구'].max()
df_delta_max['구로구'] =df_delta_max['구로구'].max()
df_delta_max['금천구'] =df_delta_max['금천구'].max()
df_delta_max['영등포구'] =df_delta_max['영등포구'].max()
df_delta_max['동작구'] =df_delta_max['동작구'].max()
df_delta_max['관악구'] =df_delta_max['관악구'].max()
df_delta_max['서초구'] =df_delta_max['서초구'].max()
df_delta_max['강남구'] =df_delta_max['강남구'].max()
df_delta_max['송파구'] =df_delta_max['송파구'].max()
df_delta_max['강동구'] =df_delta_max['강동구'].max()
df_delta_max['기타'] =df_delta_max['기타'].max()

df_delta=df_delta.loc[:,'종로구':'기타']
df_delta_max=df_delta_max.loc[:,'종로구':'기타']
df_dd=percen(df_delta, df_delta_max)
df_dd.to_excel('delta.xlsx')

###########오미크론

df_omi_max= df_omi.copy()
type(df_omi_max.max())


df_omi_max['종로구'] =df_omi_max['종로구'].max()
df_omi_max['중구'] =df_omi_max['중구'].max()
df_omi_max['용산구'] =df_omi_max['용산구'].max()
df_omi_max['성동구'] =df_omi_max['성동구'].max()
df_omi_max['광진구'] =df_omi_max['광진구'].max()
df_omi_max['동대문구'] =df_omi_max['동대문구'].max()
df_omi_max['중랑구'] =df_omi_max['중랑구'].max()
df_omi_max['성북구'] =df_omi_max['성북구'].max()
df_omi_max['강북구'] =df_omi_max['강북구'].max()
df_omi_max['도봉구'] =df_omi_max['도봉구'].max()
df_omi_max['노원구'] =df_omi_max['노원구'].max()
df_omi_max['은평구'] =df_omi_max['은평구'].max()
df_omi_max['서대문구'] =df_omi_max['서대문구'].max()
df_omi_max['마포구'] =df_omi_max['마포구'].max()
df_omi_max['양천구'] =df_omi_max['양천구'].max()
df_omi_max['강서구'] =df_omi_max['강서구'].max()
df_omi_max['구로구'] =df_omi_max['구로구'].max()
df_omi_max['금천구'] =df_omi_max['금천구'].max()
df_omi_max['영등포구'] =df_omi_max['영등포구'].max()
df_omi_max['동작구'] =df_omi_max['동작구'].max()
df_omi_max['관악구'] =df_omi_max['관악구'].max()
df_omi_max['서초구'] =df_omi_max['서초구'].max()
df_omi_max['강남구'] =df_omi_max['강남구'].max()
df_omi_max['송파구'] =df_omi_max['송파구'].max()
df_omi_max['강동구'] =df_omi_max['강동구'].max()
df_omi_max['기타'] =df_omi_max['기타'].max()

df_omi=df_omi.loc[:,'종로구':'기타']
## 맨 아래에 SUM값에 NaN 들어가 있어서 percen계산이 계속오류. 
# 맨아래 행 삭제. 
df_omi.drop(743, inplace=True)
df_omi_max=df_omi_max.loc[:,'종로구':'기타']
df_omi_max.drop(743, inplace=True)

df_oo=percen(df_omi, df_omi_max)

df_oo.to_excel('omicron.xlsx')


### 각 변이종 데이터 합치기 
df1=pd.read_excel('normal.xlsx')
df2=pd.read_excel('beta.xlsx')
df3=pd.read_excel('delta.xlsx')
df4=pd.read_excel('omicron.xlsx')
result= pd.concat([df1,df2,df3,df4 ])
result.iloc[:1,:2].head()
result.drop('Unnamed: 0', axis=1, inplace=True)

result.to_excel('new_infect.xlsx')

#########날짜 열 추가 
## 데이터프레임 정리 
df_gu=df.loc[:,'자치구 기준일':'기타']
df_date=df_gu.iloc[:,:1]
df_date.drop(743, inplace=True)

## 데이터 합치기 
result1=result.copy()
#result1.drop(axis='index', inplace=True)
result1.reset_index(inplace=True, drop=True)   
# concat오류 InvalidIndexError: Reindexing only valid with uniquely valued Index objects
# 때문에 reset index 해줌 
join=pd.concat([df_date, result1], axis=1)

join.to_excel('infect_new.xlsx')


## 변이종 이름 붙이기 
name=pd.read_excel('covid_name.xlsx')
spe=name.iloc[:,-1]

spe.reset_index(inplace=True, drop=True)

join2=pd.concat([join,spe],axis=1)
join2.drop(743, inplace=True)

join2.to_excel('infect_name.xlsx')

# 연도와 분기 추가 
join2['year'] = join2['자치구 기준일'].dt.year
join2['quarter'] = join2['자치구 기준일'].dt.quarter

join2.to_excel('quart_infect.xlsx')
